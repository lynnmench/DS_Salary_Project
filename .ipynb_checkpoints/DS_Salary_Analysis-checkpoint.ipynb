# %%
#Created: 24Jan2022
#Author: Lynn Menchaca

#Resources
#Ken Jee - Data Science Project from Scratch series
#https://www.youtube.com/playlist?list=PL2zq7klxX5ASFejJj80ob9ZAnBHdz5O1t

import Glassdoor_Scraper as gs
import pandas as pd

#chrome driver path
path = "/Users/lynnpowell/Documents/Drivers/chromedriver"

# %%
#def get_jobs(keyword, num_jobs, verbose, path, slp_time):
#df = gs.get_jobs('data scientist',1500, False, path, 10)
# Out:
# selected first job posting
# Progress: 0/1500
# In job buttons loop
# Progress: 1/1500
# In job buttons loop
# Progress: 2/1500
# In job buttons loop
# Progress: 3/1500
# In job buttons loop
# Progress: 4/1500
# In job buttons loop
# Progress: 5/1500
# In job buttons loop
# Progress: 6/1500
# In job buttons loop
# Progress: 7/1500
# In job buttons loop
# Progress: 8/1500
# In job buttons loop
# Progress: 9/1500
# In job buttons loop
# Progress: 10/1500
# In job buttons loop
# Progress: 11/1500
# In job buttons loop
# Progress: 12/1500
# In job buttons loop
# Progress: 13/1500
# In job buttons loop
# Progress: 14/1500
# In job buttons loop
# Progress: 15/1500
# In job buttons loop
# Progress: 16/1500
# In job buttons loop
# Progress: 17/1500
# In job buttons loop
# Progress: 18/1500
# In job buttons loop
# Progress: 19/1500
# In job buttons loop
# Progress: 20/1500
# In job buttons loop
# Progress: 21/1500
# In job buttons loop
# Progress: 22/1500
# In job buttons loop
# ...

# %%
#df.to_csv('Data_Science_Jobs_NoDescription.csv')
#df.to_csv('/Users/lynnpowell/Documents/DS Projects/DS_Salary_Project/Data_Science_Jobs_NoDescription.csv')

data_file_path = '/Users/lynnpowell/Documents/DS Projects/DS_Salary_Project/Data_Science_Jobs_NoDescription.csv'
salary_data = pd.read_csv(data_file_path) 
salary_data.describe()
